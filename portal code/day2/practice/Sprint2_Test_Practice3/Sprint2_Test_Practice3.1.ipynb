# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Load CSV file
file_name = "ML374_S2_DeliverybyZone_Data_Practice.xlsx"
df = pd.read_excel(file_name)
if 'Delivery_Time_Hours' not in df.columns:
    print("CSV must contain 'Delivery_Time_Hours' column.")
    exit()
df.head()
# Out:
#    Order_ID   Zone  Delivery_Time_Hours
# 0         1   East             7.648523
# 1         2   East             6.422022
# 2         3   East             6.575497
# 3         4   East             5.625316
# 4         5  South             5.819816

# %%
population_data = df['Delivery_Time_Hours']

    # Draw 200 repeated samples of size 30 with replacement
sample_size = 30
num_samples = 200
sample_means = []

for i in range(num_samples):
    sample = df.sample(n=sample_size, replace=True )['Delivery_Time_Hours']
    sample_means.append(sample.mean())
# Plot histogram with KDE
plt.figure(figsize=(10, 8))
sns.histplot(sample_means, bins=15, color='#fcbfb8', edgecolor='black', kde=True)
plt.title('Sampling Distribution of Sample Means (CLT Demonstration)')
plt.xlabel('Sample Mean Delivery Time (Hours)')
plt.ylabel('Count')
plt.show()
